# %% [markdown]
# # Cross Validation
# We've looked at a range of topics involved with fitting a model to data. This began with the simplest of regression cases and determining criteria for an optimal model, which led us to mean squarred error. From there, we further examined overfitting and underfitting which motivated train test split and later, the bias variance tradeoff. Here, we synthesize many of these ideas into a new sampling, optimization meta-routine known as cross validation.
#
# A common form of cross validation is known as K-folds. In this process, the dataset is partitioned into K equally sized groups. Each group is then used as a hold out test set while the remaining k-1 groups are used as a training set. This then produces K different models, one for each of the hold out test sets. These models can then be averaged (perhaps a weighted average based on their test set performance) in order to produce a finalized model.
#
# This is also a very useful method for helping to determine the generalization of our models, or the anticipated difference between train and test errors for the model.

# %% [markdown]
# ## 1. K-Folds
# Write a function k-folds that splits a dataset into k evenly sized pieces.
# If the full dataset is not divisible by k, make the first few folds one larger then later ones.

# %%
def kfolds(data, k):
    data = pd.DataFrame(data)
    
    df = shuffle(df)
    
    fold_size = len(data) // k
    remainder = len(data) % k
    subsets_list = []
    start_index = 0
    for start_index in range(0,remainder*fold_size, fold_size + 1):
        subsets_list.append(data[start_index: start_index + fold_size + 1])
    for start_index in range(remainder *fold_size, len(data), fold_size ):
        subsets_list.append(data[start_index:start_index + fold_size])
        
    
        
    #Force data as pandas dataframe (optional but could be helpful)
    #Be sure to account for the case where the dataset is not evenly divisible
    return subsets_list #folds should be a list of subsets of data

# %% [markdown]
# ## 2. Cross Validation
# * Split your dataset into 10 groups using your kfolds function above.
# * Perform linear regression on each and calculate the training and test error.
# * Create a simple bar chart to display the various train and test errors for each of the 10 folds.

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df = pd.read_excel('movie_data_detailed_with_ols.xlsx')
X_feats = ['budget', 'imdbRating',
       'Metascore', 'imdbVotes']
y_feat = 'domgross'
df
# Out:
#        budget   domgross                                title  Response_Json  \
# 0    13000000   25682380                        21 &amp; Over              0
# 1    45658735   13414714                             Dredd 3D              0
# 2    20000000   53107035                     12 Years a Slave              0
# 3    61000000   75612460                               2 Guns              0
# 4    40000000   95020213                                   42              0
# 5   225000000   38362475                             47 Ronin              0
# 6    92000000   67349198               A Good Day to Die Hard              0
# 7    12000000   15323921                           About Time              0
# 8    13000000   18007317                            Admission              0
# 9   130000000   60522097                          After Earth              0
# 10   40000000  148430908                      American Hustle              0
# 11   25000000   37304874                 August: Osage County              0
# 12   50000000   19452138                  Beautiful Creatures              0
# 13   18000000   33345833                         Blue Jasmine              0
# 14   55000000  107136417                     Captain Phillips              0
# 15   30000000   35266619                               Carrie              0
# 16   78000000  119640264  Cloudy with a Chance of Meatballs 2              0
# 17   76000000  368065385                      Despicable Me 2              0
# 18    5500000   24477704                              Don Jon              0
# 19  120000000   93050117                              Elysium              0
# 20  110000000   61737191                     Ender&#39;s Game              0
# 21  100000000  107518682                                 Epic              0
# 22   40000000   57012977             Escape from Planet Earth              0
# 23   70000000   25213103                          Escape Plan              0
# 24   17000000   54239856                            Evil Dead              0
# 25  160000000  238679850                   Fast and Furious 6              0
# 26  150000000  393050114                               Frozen              0
# 27  140000000  122523060                G.I. Joe: Retaliation              0
# 28   60000000   46000903                       Gangster Squad              0
# 29   30000000    4167493                               Gloria              0
#
#     Year  imdbRating  Metascore  imdbVotes         Model
# 0   2008         6.8         48     206513  4.912759e+07
# 1   2012         0.0          0          0  2.267265e+05
# 2   2013         8.1         96     537525  1.626624e+08
# 3   2013         6.7         55     173726  7.723381e+07
# 4   2013         7.5         62      74170  4.151958e+07
# 5   2013         6.3         28     128766  1.605898e+08
# 6   2013         5.3         28     180585  8.545563e+07
# 7   2013         7.8         55     240087  5.918637e+07
# 8   2013         5.7         48      30576  6.662264e+06
# 9   2013         4.9         33     174365  1.130470e+08
# 10  2013         7.3         90     398390  1.391177e+08
# 11  2013         7.2         58      75884  2.987166e+07
# 12  2013         6.2         52      76001  4.450435e+07
# 13  2013         7.3         78     170986  6.068826e+07
# 14  2013         7.8         83     368244  1.367860e+08
# 15  1976         7.4         85     142328  6.870045e+07
# 16  2013         6.4         59      75138  6.705665e+07
# 17  2013         7.4         62     324664  1.279797e+08
# 18  2013         6.6         66     208948  5.544622e+07
# 19  2013         6.6         61     378131  1.713503e+08
# 20  2013         0.0          0          0  4.339865e+07
# 21  2013         6.7         52      92389  8.146860e+07
# 22  2013         5.9         35      22430  1.465533e+07
# 23  2013         6.7         49     198767  8.586927e+07
# 24  2013         6.5         57     139940  4.076999e+07
# 25     0         0.0          0          0  2.383743e+08
# 26  2013         7.5         74     483555  2.242330e+08
# 27  2013         5.8         41     158210  1.193156e+08
# 28  2013         6.7         40     188846  7.125032e+07
# 29  1980         7.1          0          0 -1.783223e+07

# %%
folds = kfolds(df, k=10)
# Out:
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-71-296bab464f10> in <module>()
# ----> 1 folds = kfolds(df, k=10)
#
# <ipython-input-67-9598d9932494> in kfolds(data, k)
#       2     data = pd.DataFrame(data)
#       3
# ----> 4     df = shuffle(df)
#       5
#       6     fold_size = len(data) // k
#
# UnboundLocalError: local variable 'df' referenced before assignment

# %% [markdown]
# # Previews, just to demonstrate

# %%
len(df)
# Out:
# 30

# %%
folds[0]
# Out:
#       budget   domgross                                title  Response_Json  \
# 16  78000000  119640264  Cloudy with a Chance of Meatballs 2              0
# 29  30000000    4167493                               Gloria              0
# 28  60000000   46000903                       Gangster Squad              0
#
#     Year  imdbRating  Metascore  imdbVotes         Model    Random
# 16  2013         6.4         59      75138  6.705665e+07  0.040719
# 29  1980         7.1          0          0 -1.783223e+07  0.051498
# 28  2013         6.7         40     188846  7.125032e+07  0.058812

# %%
folds[1]
# Out:
#       budget  domgross     title  Response_Json  Year  imdbRating  Metascore  \
# 3   61000000  75612460    2 Guns              0  2013         6.7         55
# 4   40000000  95020213        42              0  2013         7.5         62
# 5  225000000  38362475  47 Ronin              0  2013         6.3         28
#
#    imdbVotes         Model
# 3     173726  7.723381e+07
# 4      74170  4.151958e+07
# 5     128766  1.605898e+08

# %%
folds[8]
# Out:
#        budget   domgross               title  Response_Json  Year  imdbRating  \
# 24   17000000   54239856           Evil Dead              0  2013         6.5
# 25  160000000  238679850  Fast and Furious 6              0     0         0.0
# 26  150000000  393050114              Frozen              0  2013         7.5
#
#     Metascore  imdbVotes         Model
# 24         57     139940  4.076999e+07
# 25          0          0  2.383743e+08
# 26         74     483555  2.242330e+08

# %%
folds[9]
# Out:
#        budget   domgross                  title  Response_Json  Year  \
# 27  140000000  122523060  G.I. Joe: Retaliation              0  2013
# 28   60000000   46000903         Gangster Squad              0  2013
# 29   30000000    4167493                 Gloria              0  1980
#
#     imdbRating  Metascore  imdbVotes         Model
# 27         5.8         41     158210  1.193156e+08
# 28         6.7         40     188846  7.125032e+07
# 29         7.1          0          0 -1.783223e+07

# %%
def mse(residual_col):
    residual_col = pd.Series(residual_col)
    return np.mean(residual_col.astype(float).map(lambda x: x**2))

# %%
test_errs = []
train_errs = []
k=10

for n in range(k):
    #Split into the train and test sets for this fold
    # gets all the other folds and adds to train data frame
    train = pd.concat([fold for i, fold in enumerate(folds) if i!=n])
    test = folds[n]
    
    #Fit Linear Regression Model
    
    ols = LinearRegression()
    ols.fit(train[X_feats], train[y_feat])
    #Evaluate Train and Test Errors
    y_hat_train = ols.predict(train[X_feats])
    y_hat_test = ols.predict(test[X_feats])
    train_residuals = y_hat_train - train[y_feat] 
    test_residuals = y_hat_test - test[y_feat]
#     print(y_hat_train)
#     print(train[y_feat])
#     print(train_residuals)
    train_errs.append(mse(train_residuals))
    test_errs.append(mse(test_residuals))

#Plot Train Versus Test Errors for each of the 10 folds
# plt.bar(range(k), test_errs, label='Test MSE')
# plt.bar(range(k), train_errs, label='Train MSE')
# plt.legend(bbox_to_anchor=(1,1))
to_plot = pd.DataFrame(test_errs, train_errs).reset_index()
to_plot.columns = ['Test MSE', 'Train MSE']
to_plot.plot(kind='bar')

# %%
for n, fold in enumerate(folds):
    plt.scatter(fold['budget'], fold['domgross'], label='Fold {}'.format(n))
plt.legend(bbox_to_anchor=(1,1))

# %% [markdown]
# ## 4. Analysis
# What do you notice about the train and test errors?

# %%
#Your answer here

#This dataset is poor demonstration. Some folds appear to be much more representative then others.
#Plug in better demonstrating dataset. 
# Hope would be to have train error consistently less then test error

# %% [markdown]
# ## 5. Shuffling Datasets
# Write a function to randomly sort your dataset prior to cross validation.
# Why  might you want to do this?

# %%
#Your function here
#Random Sorting
def shuffle(df):
    df['Random'] = df['Year'].map(lambda x: np.random.rand())
    return df.sort_values(by='Random')

# %%
df shuffle(df)
# Out:
#        budget   domgross                                title  Response_Json  \
# 15   30000000   35266619                               Carrie              0
# 27  140000000  122523060                G.I. Joe: Retaliation              0
# 26  150000000  393050114                               Frozen              0
# 10   40000000  148430908                      American Hustle              0
# 28   60000000   46000903                       Gangster Squad              0
# 11   25000000   37304874                 August: Osage County              0
# 13   18000000   33345833                         Blue Jasmine              0
# 9   130000000   60522097                          After Earth              0
# 16   78000000  119640264  Cloudy with a Chance of Meatballs 2              0
# 22   40000000   57012977             Escape from Planet Earth              0
# 25  160000000  238679850                   Fast and Furious 6              0
# 3    61000000   75612460                               2 Guns              0
# 19  120000000   93050117                              Elysium              0
# 0    13000000   25682380                        21 &amp; Over              0
# 21  100000000  107518682                                 Epic              0
# 12   50000000   19452138                  Beautiful Creatures              0
# 23   70000000   25213103                          Escape Plan              0
# 17   76000000  368065385                      Despicable Me 2              0
# 4    40000000   95020213                                   42              0
# 1    45658735   13414714                             Dredd 3D              0
# 20  110000000   61737191                     Ender&#39;s Game              0
# 24   17000000   54239856                            Evil Dead              0
# 14   55000000  107136417                     Captain Phillips              0
# 29   30000000    4167493                               Gloria              0
# 8    13000000   18007317                            Admission              0
# 2    20000000   53107035                     12 Years a Slave              0
# 6    92000000   67349198               A Good Day to Die Hard              0
# 5   225000000   38362475                             47 Ronin              0
# 7    12000000   15323921                           About Time              0
# 18    5500000   24477704                              Don Jon              0
#
#     Year  imdbRating  Metascore  imdbVotes         Model    Random
# 15  1976         7.4         85     142328  6.870045e+07  0.003435
# 27  2013         5.8         41     158210  1.193156e+08  0.080075
# 26  2013         7.5         74     483555  2.242330e+08  0.110154
# 10  2013         7.3         90     398390  1.391177e+08  0.130471
# 28  2013         6.7         40     188846  7.125032e+07  0.162555
# 11  2013         7.2         58      75884  2.987166e+07  0.216070
# 13  2013         7.3         78     170986  6.068826e+07  0.263148
# 9   2013         4.9         33     174365  1.130470e+08  0.302841
# 16  2013         6.4         59      75138  6.705665e+07  0.311376
# 22  2013         5.9         35      22430  1.465533e+07  0.326495
# 25     0         0.0          0          0  2.383743e+08  0.354950
# 3   2013         6.7         55     173726  7.723381e+07  0.369529
# 19  2013         6.6         61     378131  1.713503e+08  0.371069
# 0   2008         6.8         48     206513  4.912759e+07  0.380657
# 21  2013         6.7         52      92389  8.146860e+07  0.390927
# 12  2013         6.2         52      76001  4.450435e+07  0.461298
# 23  2013         6.7         49     198767  8.586927e+07  0.535221
# 17  2013         7.4         62     324664  1.279797e+08  0.570889
# 4   2013         7.5         62      74170  4.151958e+07  0.585604
# 1   2012         0.0          0          0  2.267265e+05  0.589883
# 20  2013         0.0          0          0  4.339865e+07  0.634097
# 24  2013         6.5         57     139940  4.076999e+07  0.675713
# 14  2013         7.8         83     368244  1.367860e+08  0.694505
# 29  1980         7.1          0          0 -1.783223e+07  0.700920
# 8   2013         5.7         48      30576  6.662264e+06  0.730706
# 2   2013         8.1         96     537525  1.626624e+08  0.804592
# 6   2013         5.3         28     180585  8.545563e+07  0.869518
# 5   2013         6.3         28     128766  1.605898e+08  0.914905
# 7   2013         7.8         55     240087  5.918637e+07  0.930439
# 18  2013         6.6         66     208948  5.544622e+07  0.986809

# %%
#Your answer here
# maybe data is organized in some way
df
# Out:
#        budget   domgross                                title  Response_Json  \
# 16   78000000  119640264  Cloudy with a Chance of Meatballs 2              0
# 29   30000000    4167493                               Gloria              0
# 28   60000000   46000903                       Gangster Squad              0
# 13   18000000   33345833                         Blue Jasmine              0
# 7    12000000   15323921                           About Time              0
# 23   70000000   25213103                          Escape Plan              0
# 8    13000000   18007317                            Admission              0
# 27  140000000  122523060                G.I. Joe: Retaliation              0
# 0    13000000   25682380                        21 &amp; Over              0
# 19  120000000   93050117                              Elysium              0
# 26  150000000  393050114                               Frozen              0
# 15   30000000   35266619                               Carrie              0
# 25  160000000  238679850                   Fast and Furious 6              0
# 11   25000000   37304874                 August: Osage County              0
# 20  110000000   61737191                     Ender&#39;s Game              0
# 6    92000000   67349198               A Good Day to Die Hard              0
# 4    40000000   95020213                                   42              0
# 3    61000000   75612460                               2 Guns              0
# 17   76000000  368065385                      Despicable Me 2              0
# 24   17000000   54239856                            Evil Dead              0
# 18    5500000   24477704                              Don Jon              0
# 14   55000000  107136417                     Captain Phillips              0
# 5   225000000   38362475                             47 Ronin              0
# 10   40000000  148430908                      American Hustle              0
# 12   50000000   19452138                  Beautiful Creatures              0
# 21  100000000  107518682                                 Epic              0
# 1    45658735   13414714                             Dredd 3D              0
# 22   40000000   57012977             Escape from Planet Earth              0
# 2    20000000   53107035                     12 Years a Slave              0
# 9   130000000   60522097                          After Earth              0
#
#     Year  imdbRating  Metascore  imdbVotes         Model    Random
# 16  2013         6.4         59      75138  6.705665e+07  0.311376
# 29  1980         7.1          0          0 -1.783223e+07  0.700920
# 28  2013         6.7         40     188846  7.125032e+07  0.162555
# 13  2013         7.3         78     170986  6.068826e+07  0.263148
# 7   2013         7.8         55     240087  5.918637e+07  0.930439
# 23  2013         6.7         49     198767  8.586927e+07  0.535221
# 8   2013         5.7         48      30576  6.662264e+06  0.730706
# 27  2013         5.8         41     158210  1.193156e+08  0.080075
# 0   2008         6.8         48     206513  4.912759e+07  0.380657
# 19  2013         6.6         61     378131  1.713503e+08  0.371069
# 26  2013         7.5         74     483555  2.242330e+08  0.110154
# 15  1976         7.4         85     142328  6.870045e+07  0.003435
# 25     0         0.0          0          0  2.383743e+08  0.354950
# 11  2013         7.2         58      75884  2.987166e+07  0.216070
# 20  2013         0.0          0          0  4.339865e+07  0.634097
# 6   2013         5.3         28     180585  8.545563e+07  0.869518
# 4   2013         7.5         62      74170  4.151958e+07  0.585604
# 3   2013         6.7         55     173726  7.723381e+07  0.369529
# 17  2013         7.4         62     324664  1.279797e+08  0.570889
# 24  2013         6.5         57     139940  4.076999e+07  0.675713
# 18  2013         6.6         66     208948  5.544622e+07  0.986809
# 14  2013         7.8         83     368244  1.367860e+08  0.694505
# 5   2013         6.3         28     128766  1.605898e+08  0.914905
# 10  2013         7.3         90     398390  1.391177e+08  0.130471
# 12  2013         6.2         52      76001  4.450435e+07  0.461298
# 21  2013         6.7         52      92389  8.146860e+07  0.390927
# 1   2012         0.0          0          0  2.267265e+05  0.589883
# 22  2013         5.9         35      22430  1.465533e+07  0.326495
# 2   2013         8.1         96     537525  1.626624e+08  0.804592
# 9   2013         4.9         33     174365  1.130470e+08  0.302841
